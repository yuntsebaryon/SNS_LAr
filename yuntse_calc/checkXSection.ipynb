# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
fXSection = '/Users/yuntse/work/sns/SNS_LAr/Neutrino_info/Neutrino_Xsections.csv'

# %%
XSection = pd.read_csv(fXSection, header=1, names = [ 'IBDE', 'IBD', 'nue_e-E', 'nue_e-', 'nueb_e-E', 'nueb_e-', 'nux_e-E', 'nux_e-', 'nuxb_e-E', 'nuxb_e-', 'conNC-pE', 'conNC-p', 'nue_ArE', 'nue_Ar'])

# %%
XSection
# Out:
#           IBDE       IBD   nue_e-E    nue_e-  nueb_e-E   nueb_e-   nux_e-E  \
# 0     5.196367  0.000134  5.266557  0.000004  5.447351  0.000002  5.234653
# 1     5.725188  0.000166  6.255604  0.000005  6.207747  0.000002  6.287508
# 2     6.200302  0.000205  7.072365  0.000006  6.957508  0.000003  7.404174
# 3     6.676746  0.000248  7.531793  0.000006  7.712586  0.000003  8.552744
# 4     7.199983  0.000307  8.552744  0.000007  8.498050  0.000003  9.676499
# ..         ...       ...       ...       ...       ...       ...       ...
# 131  98.077395  0.042952       NaN       NaN       NaN       NaN       NaN
# 132  98.779299  0.043811       NaN       NaN       NaN       NaN       NaN
# 133  99.417394  0.043799       NaN       NaN       NaN       NaN       NaN
# 134        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 135        NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
# ...

# %%
XSection['IBD']
# Out:
# 0      0.000134
# 1      0.000166
# 2      0.000205
# 3      0.000248
# 4      0.000307
#          ...
# 131    0.042952
# 132    0.043811
# 133    0.043799
# 134         NaN
# 135         NaN
# Name: IBD, Length: 136, dtype: float64

# %%
FAC = 1e-38

# %%
plt.figure(figsize = (10,8))
plt.plot(XSection['IBDE'], XSection['IBD']*FAC, label = 'IBD', lw = 2)
plt.plot(XSection['nue_e-E'], XSection['nue_e-']*FAC, label = r'$\nu_e$-e', lw = 2)
plt.plot(XSection['nueb_e-E'], XSection['nueb_e-']*FAC, label = r'$\overline{\nu}_e$-e', lw = 2)
plt.plot(XSection['nux_e-E'], XSection['nux_e-']*FAC, label = r'$\nu_x$-e', lw = 2)
plt.plot(XSection['nuxb_e-E'], XSection['nuxb_e-']*FAC, label = r'$\overline{\nu}_x$-e', lw = 2)
plt.plot(XSection['conNC-pE'], XSection['conNC-p']*FAC, label = 'CNC', lw = 2)
plt.plot(XSection['nue_ArE'], XSection['nue_Ar']*FAC, label = r'$\nu_e$-Ar', lw = 2)

plt.legend(loc='upper left', ncol = 3, fontsize = 18)
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
plt.grid(which = "both", linestyle = '--')
plt.xlabel('Energy [MeV]', fontsize = 18)
plt.ylabel(r'Cross-section [cm$^2$]', fontsize = 18)

plt.semilogy()
plt.xlim(5, 100)
plt.ylim(4e-45, 4e-37)
plt.show()

# %%
fXSNueAr40Marley = '/Users/yuntse/work/supernova/SNOwGLoBES/xscns/xs_nue_Ar40_marley.dat'
fXSNueAr40Marley1 = '/Users/yuntse/work/supernova/SNOwGLoBES/xscns/xs_nue_Ar40_marley1.dat'
fXSNueAr40Marley2 = '/Users/yuntse/work/supernova/SNOwGLoBES/xscns/xs_nue_Ar40_marley2.dat'

# %%
XSNueAr40Marley = pd.read_csv( fXSNueAr40Marley, header = None, sep = r'\s+', names = ['E', 'nu_e', 'nu_mu', 'nu_tau', 'nu_e_bar', 'nu_mu_bar', 'nu_tar_bar'])

# %%
XSNueAr40Marley
# Out:
#            E      nu_e  nu_mu  nu_tau  nu_e_bar  nu_mu_bar  nu_tar_bar
# 0   -2.30103  0.001706      0       0         0          0           0
# 1   -2.29973  0.001738      0       0         0          0           0
# 2   -2.29843  0.001771      0       0         0          0           0
# 3   -2.29712  0.001804      0       0         0          0           0
# 4   -2.29582  0.001837      0       0         0          0           0
# ..       ...       ...    ...     ...       ...        ...         ...
# 995 -1.00521  3.689300      0       0         0          0           0
# 996 -1.00391  3.703140      0       0         0          0           0
# 997 -1.00260  3.717040      0       0         0          0           0
# 998 -1.00130  3.730970      0       0         0          0           0
# 999 -1.00000  3.744940      0       0         0          0           0
#
# [1000 rows x 7 columns]

# %%
XSNueAr40Marley1 = pd.read_csv( fXSNueAr40Marley1, header = None, sep = r'\s+', names = ['E', 'nu_e', 'nu_mu', 'nu_tau', 'nu_e_bar', 'nu_mu_bar', 'nu_tar_bar'])

# %%
XSNueAr40Marley1
# Out:
#            E      nu_e  nu_mu  nu_tau  nu_e_bar  nu_mu_bar  nu_tar_bar
# 0   -2.30103  0.002164      0       0         0          0           0
# 1   -2.29973  0.002204      0       0         0          0           0
# 2   -2.29843  0.002245      0       0         0          0           0
# 3   -2.29712  0.002287      0       0         0          0           0
# 4   -2.29582  0.002330      0       0         0          0           0
# ..       ...       ...    ...     ...       ...        ...         ...
# 995 -1.00521  3.768960      0       0         0          0           0
# 996 -1.00391  3.783000      0       0         0          0           0
# 997 -1.00260  3.797080      0       0         0          0           0
# 998 -1.00130  3.811200      0       0         0          0           0
# 999 -1.00000  3.825370      0       0         0          0           0
#
# [1000 rows x 7 columns]

# %%
XSNueAr40Marley2 = pd.read_csv( fXSNueAr40Marley2, header = None, sep = r'\s+', names = ['E', 'nu_e', 'nu_mu', 'nu_tau', 'nu_e_bar', 'nu_mu_bar', 'nu_tar_bar'])

# %%
XSNueAr40Marley2
# Out:
#            E      nu_e  nu_mu  nu_tau  nu_e_bar  nu_mu_bar  nu_tar_bar
# 0   -2.30103  0.001706      0       0         0          0           0
# 1   -2.29973  0.001738      0       0         0          0           0
# 2   -2.29843  0.001771      0       0         0          0           0
# 3   -2.29712  0.001804      0       0         0          0           0
# 4   -2.29582  0.001837      0       0         0          0           0
# ..       ...       ...    ...     ...       ...        ...         ...
# 995 -1.00521  3.689300      0       0         0          0           0
# 996 -1.00391  3.703140      0       0         0          0           0
# 997 -1.00260  3.717040      0       0         0          0           0
# 998 -1.00130  3.730970      0       0         0          0           0
# 999 -1.00000  3.744940      0       0         0          0           0
#
# [1000 rows x 7 columns]

# %%
plt.figure(figsize = (10,8))
plt.plot(XSection['nue_ArE'], XSection['nue_Ar']*FAC, label = '1211.5199', lw = 2)
plt.plot(10**XSNueAr40Marley['E']*1000, (10**XSNueAr40Marley['E'])*XSNueAr40Marley['nu_e']*FAC, label = 'Marley', lw = 2)
plt.plot(10**XSNueAr40Marley1['E']*1000, (10**XSNueAr40Marley1['E'])*XSNueAr40Marley1['nu_e']*FAC, label = 'Marley1', lw = 2)
plt.plot(10**XSNueAr40Marley2['E']*1000, (10**XSNueAr40Marley2['E'])*XSNueAr40Marley2['nu_e']*FAC, label = 'Marley2', lw = 2)

plt.legend(loc='upper left', ncol = 3, fontsize = 18)
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
plt.grid(which = "both", linestyle = '--')
plt.xlabel('Energy [MeV]', fontsize = 18)
plt.ylabel(r'Cross-section [cm$^2$]', fontsize = 18)

plt.semilogy()
plt.xlim(5, 100)
plt.ylim(4e-43, 4e-37)
plt.savefig('compNueArXSection.pdf')
plt.show()

# %%
XSNueAr40Marley['E'] = 10**XSNueAr40Marley['E']
XSNueAr40Marley1['E'] = 10**XSNueAr40Marley1['E']
XSNueAr40Marley2['E'] = 10**XSNueAr40Marley2['E']
XSNueAr40Marley['nu_e'] *= XSNueAr40Marley['E']*FAC
XSNueAr40Marley1['nu_e'] *= XSNueAr40Marley1['E']*FAC
XSNueAr40Marley2['nu_e'] *= XSNueAr40Marley2['E']*FAC

# %%
plt.figure(figsize = (10,8))
plt.plot(XSection['nue_ArE'], XSection['nue_Ar']*FAC, label = '1211.5199', lw = 2)
plt.plot(XSNueAr40Marley['E']*1000, XSNueAr40Marley['nu_e'], label = 'Marley', lw = 2)
plt.plot(XSNueAr40Marley1['E']*1000, XSNueAr40Marley1['nu_e'], label = 'Marley1', lw = 2)
plt.plot(XSNueAr40Marley2['E']*1000, XSNueAr40Marley2['nu_e'], label = 'Marley2', lw = 2)

plt.legend(loc='upper left', ncol = 3, fontsize = 18)
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
plt.grid(which = "both", linestyle = '--')
plt.xlabel('Energy [MeV]', fontsize = 18)
plt.ylabel(r'Cross-section [cm$^2$]', fontsize = 18)

plt.semilogy()
plt.xlim(5, 100)
plt.ylim(4e-43, 4e-37)
plt.show()

# %%
# nue-e CC
fXSNuE = '/Users/yuntse/work/supernova/SNOwGLoBES/xscns/xs_nue_e.dat'

# %%
XSNuE = pd.read_csv( fXSNuE, header = None, skiprows = 3, sep = r'\s+', names = ['E', 'nu_e', 'nu_mu', 'nu_tau', 'nu_e_bar', 'nu_mu_bar', 'nu_tau_bar'])
XSNuE
# Out:
#              E      nu_e     nu_mu    nu_tau  nu_e_bar  nu_mu_bar  nu_tau_bar
# 0    -3.301030  0.000560  0.000139  0.000138  0.000285   0.000128    0.000129
# 1    -3.298729  0.000561  0.000140  0.000138  0.000285   0.000128    0.000129
# 2    -3.296428  0.000562  0.000140  0.000138  0.000285   0.000128    0.000129
# 3    -3.294127  0.000563  0.000140  0.000139  0.000286   0.000128    0.000129
# 4    -3.291826  0.000565  0.000140  0.000139  0.000286   0.000128    0.000129
# ...        ...       ...       ...       ...       ...        ...         ...
# 996  -1.009204  0.000918  0.000158  0.000157  0.000386   0.000135    0.000137
# 997  -1.006903  0.000918  0.000158  0.000157  0.000386   0.000135    0.000137
# 998  -1.004602  0.000918  0.000158  0.000157  0.000386   0.000135    0.000137
# 999  -1.002301  0.000918  0.000158  0.000157  0.000386   0.000135    0.000137
# 1000 -1.000000  0.000918  0.000158  0.000157  0.000386   0.000135    0.000137
#
# [1001 rows x 7 columns]

# %%
# Sanity checks
plt.figure(figsize = (10,8))
plt.plot(XSection['nue_e-E'], XSection['nue_e-']*FAC, label = r'$\nu_e$-e (1)', lw = 2)
plt.plot(10**XSNuE['E']*1000, (10**XSNuE['E'])*XSNuE['nu_e']*FAC, label = r'$\nu_e$-e (2)', lw = 2)
plt.plot(XSection['nueb_e-E'], XSection['nueb_e-']*FAC, label = r'$\overline{\nu}_e$-e (1)', lw = 2)
plt.plot(10**XSNuE['E']*1000, (10**XSNuE['E'])*XSNuE['nu_e_bar']*FAC, label = r'$\overline{\nu}_e$-e (2)', lw = 2)
plt.plot(XSection['nux_e-E'], XSection['nux_e-']*FAC, label = r'$\nu_x$-e (1)', lw = 2)
plt.plot(10**XSNuE['E']*1000, (10**XSNuE['E'])*XSNuE['nu_mu']*FAC, label = r'$\nu_{\mu}$-e (2)', lw = 2)
plt.plot(10**XSNuE['E']*1000, (10**XSNuE['E'])*XSNuE['nu_tau']*FAC, label = r'$\nu_{\tau}$-e (2)', lw = 2)
plt.plot(XSection['nuxb_e-E'], XSection['nuxb_e-']*FAC, label = r'$\overline{\nu}_x$-e (1)', lw = 2)
plt.plot(10**XSNuE['E']*1000, (10**XSNuE['E'])*XSNuE['nu_mu_bar']*FAC, label = r'$\overline{\nu}_{\mu}$-e (2)', lw = 2)
plt.plot(10**XSNuE['E']*1000, (10**XSNuE['E'])*XSNuE['nu_tau_bar']*FAC, label = r'$\overline{\nu}_{\tau}$-e (2)', lw = 2)

plt.legend(loc='upper left', ncol = 3, fontsize = 18)
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
plt.grid(which = "both", linestyle = '--')
plt.xlabel('Energy [MeV]', fontsize = 18)
plt.ylabel(r'Cross-section [cm$^2$]', fontsize = 18)

plt.semilogy()
plt.xlim(5, 100)
plt.ylim(4e-45, 4e-41)
plt.show()
